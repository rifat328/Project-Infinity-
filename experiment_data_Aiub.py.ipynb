# %%
import pandas as pd
import html5lib
url='https://www.aiub.edu/faculties/fst/ug-course-catalog'
url2='https://en.wikipedia.org/wiki/List_of_timelines#Environment'
html1='core.html'
html2='elective.html'

# %%
list_of_df=pd.read_html(html1)

# %%
list_of_df[3]
# Out:
#       Code                                          Name  \
# 0  MAT1102  DIFFERENTIAL CALCULUS & CO-ORDINATE GEOMETRY
# 1  PHY1101                                     PHYSICS 1
# 2  PHY1102                                 PHYSICS 1 LAB
# 3  ENG1101      ENGLISH READING SKILLS & PUBLIC SPEAKING
# 4  CSC1102                   INTRODUCTION TO PROGRAMMING
# 5  CSC1103               INTRODUCTION TO PROGRAMMING LAB
# 6  CSC1101              INTRODUCTION TO COMPUTER STUDIES
#
#   Credit(Lec-Sci-Comp-Lan-Stu)  Pre-Requisite
# 0                    3 0 0 0 0            NaN
# 1                    3 0 0 0 0            NaN
# 2                    1 1 0 0 0            NaN
# 3                    3 0 0 1 0            NaN
# 4                    3 0 0 0 0            NaN
# 5                    1 0 1 0 0            NaN
# 6                    1 0 1 0 0            NaN

# %%
list_of_df[4]
# Out:
#       Code                                               Name  \
# 0  CSC1204                               DISCRETE MATHEMATICS
# 1  MAT1205  INTEGRAL CALCULUS & ORDINARY DIFFERENTIAL EQUA...
# 2  CSC1205                      OBJECT ORIENTED PROGRAMMING 1
# 3  PHY1203                                          PHYSICS 2
# 4  PHY1204                                      PHYSICS 2 LAB
# 5  ENG1202             ENGLISH WRITING SKILLS & COMMUNICATION
# 6  COE2101                INTRODUCTION TO ELECTRICAL CIRCUITS
# 7  COE2102            INTRODUCTION TO ELECTRICAL CIRCUITS LAB
#
#   Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                    3 0 0 0 0  MAT1102  CSC1102
# 1                    3 0 0 0 0           MAT1102
# 2                    3 0 1 0 0  CSC1102  CSC1103
# 3                    3 0 0 0 0           PHY1101
# 4                    1 1 0 0 0           PHY1102
# 5                    3 0 0 1 0           ENG1101
# 6                    3 0 0 0 0           PHY1101
# ...

# %%
list_of_df[5]
# Out:
#        Code                                         Name  \
# 0  CHEM1101                                    CHEMISTRY
# 1   MAT2101  COMPLEX VARIABLE,LAPLACE & Z-TRANSFORMATION
# 2   CSC2108                     INTRODUCTION TO DATABASE
# 3   EEE2104                       ELECTRONIC DEVICES LAB
# 4   BBA1102                     PRINCIPLES OF ACCOUNTING
# 5   EEE2103                           ELECTRONIC DEVICES
# 6   CSC2106                               DATA STRUCTURE
# 7   CSC2107                           DATA STRUCTURE LAB
# 8   BAE2101             COMPUTER AIDED DESIGN & DRAFTING
#
#   Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                    3 1 0 0 0           PHY1203
# 1                    3 0 0 0 0           MAT1205
# 2                    3 0 1 0 0           CSC1205
# 3                    1 1 0 0 0           COE2102
# 4                    3 0 0 0 0           MAT1205
# 5                    3 0 0 0 0           COE2101
# ...

# %%
list_of_df[6]
# Out:
#       Code                                      Name  \
# 0  CSC2211                                ALGORITHMS
# 1  MAT2202       MATRICES, VECTORS, FOURIER ANALYSIS
# 2  CSC2210             OBJECT ORIENTED PROGRAMMING 2
# 3  CSC2209       OBJECT ORIENTED ANALYSIS AND DESIGN
# 4  BAS2101                        BANGLADESH STUDIES
# 5  EEE3101                DIGITAL LOGIC AND CIRCUITS
# 6  EEE3102            DIGITAL LOGIC AND CIRCUITS LAB
# 7  MAT3103  COMPUTATIONAL STATISTICS AND PROBABILITY
#
#   Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                    3 0 1 0 0  CSC2106  CSC2107
# 1                    3 0 0 0 0           MAT2101
# 2                    3 0 1 0 0  CSC2108  CSC1205
# 3                    3 0 0 0 0           CSC2108
# 4                    3 0 0 0 0           CSC1101
# 5                    3 0 0 0 0           EEE2103
# 6                    1 1 0 0 0           EEE2104
# 7                    3 0 0 0 0           MAT2101

# %%
list_of_df[7]
# Out:
#       Code                                           Name  \
# 0  CSC3113                          THEORY OF COMPUTATION
# 1  ECO3150                        PRINCIPLES OF ECONOMICS
# 2  ENG2103                         BUSINESS COMMUNICATION
# 3  MAT3101  NUMERICAL METHODS FOR SCIENCE AND ENGINEERING
# 4  COE3103                             DATA COMMUNICATION
# 5  COE3104             MICROPROCESSOR AND EMBEDDED SYSTEM
# 6  CSC3112                           SOFTWARE ENGINEERING
#
#   Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                    3 0 0 0 0           CSC2211
# 1                    2 0 0 0 0           MAT3103
# 2                    3 0 0 0 0           BAS2101
# 3                    3 0 0 0 0           MAT2202
# 4                    3 1 0 0 0  EEE3101  EEE3102
# 5                    3 1 0 0 0  EEE3101  EEE3102
# 6                    3 0 1 0 0  CSC2209  CSC2210

# %%
list_of_df[8]
# Out:
#       Code                                     Name  \
# 0  CSC3217  ARTIFICIAL INTELLIGENCE AND EXPERT SYS.
# 1  COE3206                        COMPUTER NETWORKS
# 2  COE3205   COMPUTER ORGANIZATION AND ARCHITECTURE
# 3  CSC3214                         OPERATING SYSTEM
# 4  CSC3215                         WEB TECHNOLOGIES
# 5  EEE2216                       ENGINEERING ETHICS
# 6  CSC3216                          COMPILER DESIGN
#
#   Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                    3 0 1 0 0  CSC2211  MAT3103
# 1                    3 1 0 0 0           COE3103
# 2                    3 0 1 0 0           COE3104
# 3                    3 0 1 0 0  CSC2211  COE3104
# 4                    3 0 1 0 0           CSC3112
# 5                    2 0 0 0 0  CSC3112  COE3104
# 6                    3 0 1 0 0           CSC3113

# %%
list_of_df[9]
# Out:
#       Code                    Name Credit(Lec-Sci-Comp-Lan-Stu)  \
# 0  CSC4118       COMPUTER GRAPHICS                    3 0 1 0 0
# 1  CSC****          COS ELECTIVE 1                    3 0 0 0 0
# 2  MGT3202  ENGINEERING MANAGEMENT                    3 0 0 0 0
# 3  CSC4197    RESEARCH METHODOLOGY                    3 0 0 0 0
# 4  CSC####             CSE MAJOR 1                    3 0 0 0 0
# 5  CSC####             CSE MAJOR 2                    3 0 0 0 0
# 6  CSC####             CSE MAJOR 3                    3 0 0 0 0
#
#       Pre-Requisite
# 0  CSC2211  MAT2202
# 1               NaN
# 2           EEE2216
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN

# %%
len(list_of_df)
# Out:
# 11

# %%
list_of_df[10]
# Out:
#       Code              Name Credit(Lec-Sci-Comp-Lan-Stu) Pre-Requisite
# 0  CSC4298  THESIS / PROJECT                    3 0 0 0 0       CSC4197
# 1  CSC****    COS ELECTIVE 2                    3 0 0 0 0           NaN
# 2  CSC4299        INTERNSHIP                    3 0 0 0 0           NaN

# %%
#Core range found 3 to 10 from list. total len 11     list_of_df[10]    maximum

# %%
#elective
list_of_df2=pd.read_html(html2)
len(list_of_df2)
# Out:
# 4

# %%
list_of_df2[3:4]
# Out:
# [       Code                                               Name  \
#  0   CSC4181                 ADVANCE DATABASE MANAGEMENT SYSTEM
#  1   BAE1201                             BASIC MECHANICAL ENGG.
#  2   CSC4125                       COMPUTER SCIENCE MATHEMATICS
#  3   MIS3101                      MANAGEMENT INFORMATION SYSTEM
#  4   EEE2213                            SIGNALS & LINEAR SYSTEM
#  5   CSC4126                                 BASIC GRAPH THEORY
#  6   COE4128                              DIGITAL SYSTEM DESIGN
#  7   COE4231                                   IMAGE PROCESSING
#  8   COE4129                                 MULTIMEDIA SYSTEMS
#  9   COE4230                              SIMULATION & MODELING
#  10  MIS4011                       ENTERPRISE RESOURCE PLANNING
#  11  CSC4285                     DATA WAREHOUSE AND DATA MINING
#  12  CSC4233                        NATURAL LANGUAGE PROCESSING
#  13  CSC4270            SOFTWARE DEVELOPMENT PROJECT MANAGEMENT
# ...

# %%
for list in list_of_df2[3:4]:
    print(list)
# Out:
#        Code                                               Name  \
# 0   CSC4181                 ADVANCE DATABASE MANAGEMENT SYSTEM
# 1   BAE1201                             BASIC MECHANICAL ENGG.
# 2   CSC4125                       COMPUTER SCIENCE MATHEMATICS
# 3   MIS3101                      MANAGEMENT INFORMATION SYSTEM
# 4   EEE2213                            SIGNALS & LINEAR SYSTEM
# 5   CSC4126                                 BASIC GRAPH THEORY
# 6   COE4128                              DIGITAL SYSTEM DESIGN
# 7   COE4231                                   IMAGE PROCESSING
# 8   COE4129                                 MULTIMEDIA SYSTEMS
# 9   COE4230                              SIMULATION & MODELING
# 10  MIS4011                       ENTERPRISE RESOURCE PLANNING
# 11  CSC4285                     DATA WAREHOUSE AND DATA MINING
# 12  CSC4233                        NATURAL LANGUAGE PROCESSING
# 13  CSC4270            SOFTWARE DEVELOPMENT PROJECT MANAGEMENT
# ...

# %%
list_of_df2[3]
# Out:
#        Code                                               Name  \
# 0   CSC4181                 ADVANCE DATABASE MANAGEMENT SYSTEM
# 1   BAE1201                             BASIC MECHANICAL ENGG.
# 2   CSC4125                       COMPUTER SCIENCE MATHEMATICS
# 3   MIS3101                      MANAGEMENT INFORMATION SYSTEM
# 4   EEE2213                            SIGNALS & LINEAR SYSTEM
# 5   CSC4126                                 BASIC GRAPH THEORY
# 6   COE4128                              DIGITAL SYSTEM DESIGN
# 7   COE4231                                   IMAGE PROCESSING
# 8   COE4129                                 MULTIMEDIA SYSTEMS
# 9   COE4230                              SIMULATION & MODELING
# 10  MIS4011                       ENTERPRISE RESOURCE PLANNING
# 11  CSC4285                     DATA WAREHOUSE AND DATA MINING
# 12  CSC4233                        NATURAL LANGUAGE PROCESSING
# 13  CSC4270            SOFTWARE DEVELOPMENT PROJECT MANAGEMENT
# ...

# %%
#work left data cleaning ,
# processing,
# adding those 2 data frams to one final dataframes .csv file
#then application work

# %%
#experiment on dataframs
df_all_rows = pd.concat([list_of_df[3],list_of_df[4],list_of_df[5],list_of_df[6],list_of_df[7],list_of_df[8],list_of_df[9],list_of_df[10], list_of_df2[3]], ignore_index=True)
df_all_rows
# Out:
#         Code                                          Name  \
# 0    MAT1102  DIFFERENTIAL CALCULUS & CO-ORDINATE GEOMETRY
# 1    PHY1101                                     PHYSICS 1
# 2    PHY1102                                 PHYSICS 1 LAB
# 3    ENG1101      ENGLISH READING SKILLS & PUBLIC SPEAKING
# 4    CSC1102                   INTRODUCTION TO PROGRAMMING
# ..       ...                                           ...
# 96   CSC4273     SOFTWARE ARCHITECTURE AND DESIGN PATTERNS
# 97   MIS4007                             DIGITAL MARKETING
# 98   MIS4012           E-COMMERCE, E-GOVERNANCE & E-SERIES
# 99   EEE3103                     DIGITAL SIGNAL PROCESSING
# 100  EEE4217                           VLSI CIRCUIT DESIGN
#
#     Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                      3 0 0 0 0               NaN
# 1                      3 0 0 0 0               NaN
# 2                      1 1 0 0 0               NaN
# ...

# %%
df_all_rows.head(30)
# Out:
#         Code                                               Name  \
# 0    MAT1102       DIFFERENTIAL CALCULUS & CO-ORDINATE GEOMETRY
# 1    PHY1101                                          PHYSICS 1
# 2    PHY1102                                      PHYSICS 1 LAB
# 3    ENG1101           ENGLISH READING SKILLS & PUBLIC SPEAKING
# 4    CSC1102                        INTRODUCTION TO PROGRAMMING
# 5    CSC1103                    INTRODUCTION TO PROGRAMMING LAB
# 6    CSC1101                   INTRODUCTION TO COMPUTER STUDIES
# 7    CSC1204                               DISCRETE MATHEMATICS
# 8    MAT1205  INTEGRAL CALCULUS & ORDINARY DIFFERENTIAL EQUA...
# 9    CSC1205                      OBJECT ORIENTED PROGRAMMING 1
# 10   PHY1203                                          PHYSICS 2
# 11   PHY1204                                      PHYSICS 2 LAB
# 12   ENG1202             ENGLISH WRITING SKILLS & COMMUNICATION
# 13   COE2101                INTRODUCTION TO ELECTRICAL CIRCUITS
# ...

# %%
df_all_rows.tail(105)
# Out:
#         Code                                          Name  \
# 0    MAT1102  DIFFERENTIAL CALCULUS & CO-ORDINATE GEOMETRY
# 1    PHY1101                                     PHYSICS 1
# 2    PHY1102                                 PHYSICS 1 LAB
# 3    ENG1101      ENGLISH READING SKILLS & PUBLIC SPEAKING
# 4    CSC1102                   INTRODUCTION TO PROGRAMMING
# ..       ...                                           ...
# 96   CSC4273     SOFTWARE ARCHITECTURE AND DESIGN PATTERNS
# 97   MIS4007                             DIGITAL MARKETING
# 98   MIS4012           E-COMMERCE, E-GOVERNANCE & E-SERIES
# 99   EEE3103                     DIGITAL SIGNAL PROCESSING
# 100  EEE4217                           VLSI CIRCUIT DESIGN
#
#     Credit(Lec-Sci-Comp-Lan-Stu)     Pre-Requisite
# 0                      3 0 0 0 0               NaN
# 1                      3 0 0 0 0               NaN
# 2                      1 1 0 0 0               NaN
# ...

# %%
len(df_all_rows)
# Out:
# 101

# %%
total=0
for size in list_of_df[3:11]:
    total+=len(size)

# %%
total
# Out:
# 56

# %%
for size in list_of_df2[3]:
    total+=len(size)

# %%
total
# Out:
# 105

# %%
final=df_all_rows
df_all_rows.to_csv('course_data.csv')

# %%
#work left: data cleaning , preprocessing & attachment.
